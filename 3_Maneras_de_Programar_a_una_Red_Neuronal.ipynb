# %% [markdown]
# <a href="https://colab.research.google.com/github/4escofet/initial_projects/blob/main/3_Maneras_de_Programar_a_una_Red_Neuronal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3 Maneras de Programar a una Red Neuronal - DOTCSV
#
# ## Código inicial

# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

from sklearn.datasets import make_circles

# Creamos nuestros datos artificiales, donde buscaremos clasificar 
# dos anillos concéntricos de datos. 
X, Y = make_circles(n_samples=500, factor=0.5, noise=0.05)

# Resolución del mapa de predicción.
res = 100 

# Coordendadas del mapa de predicción.
_x0 = np.linspace(-1.5, 1.5, res)
_x1 = np.linspace(-1.5, 1.5, res)

# Input con cada combo de coordenadas del mapa de predicción.
_pX = np.array(np.meshgrid(_x0, _x1)).T.reshape(-1, 2)

# Objeto vacio a 0.5 del mapa de predicción.
_pY = np.zeros((res, res)) + 0.5

# Visualización del mapa de predicción.
plt.figure(figsize=(8, 8))
plt.pcolormesh(_x0, _x1, _pY, cmap="coolwarm", vmin=0, vmax=1)

# Visualización de la nube de datos.
plt.scatter(X[Y == 0,0], X[Y == 0,1], c="skyblue")
plt.scatter(X[Y == 1,0], X[Y == 1,1], c="salmon")

plt.tick_params(labelbottom=False, labelleft=False)

# %% [markdown]
# ## Tensorflow

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

from matplotlib import animation
from IPython.core.display import display, HTML

# Definimos los puntos de entrada de la red, para la matriz X e Y.
iX = tf.placeholder('float', shape=[None, X.shape[1]])
#x = tf.placeholder(shape=[None, 2], dtype=tf.float32)
iY = tf.placeholder('float', shape=[None])

lr = 0.01           # learning rate
nn = [2, 16, 8, 1]  # número de neuronas por capa.

# Capa 1
W1 = tf.Variable(tf.random_normal([nn[0], nn[1]]), name='Weights_1')
b1 = tf.Variable(tf.random_normal([nn[1]]), name='bias_1')

l1 = tf.nn.relu(tf.add(tf.matmul(iX, W1), b1))

# Capa 2
W2 = tf.Variable(tf.random_normal([nn[1], nn[2]]), name='Weights_2')
b2 = tf.Variable(tf.random_normal([nn[2]]), name='bias_2')

l2 = tf.nn.relu(tf.add(tf.matmul(l1, W2), b2))

# Capa 3
W3 = tf.Variable(tf.random_normal([nn[2], nn[3]]), name='Weights_3')
b3 = tf.Variable(tf.random_normal([nn[3]]), name='bias_3')

# Vector de predicciones de Y.
pY = tf.nn.sigmoid(tf.add(tf.matmul(l2, W3), b3))[:, 0]


# Evaluación de las predicciones.
loss = tf.losses.mean_squared_error(pY, iY)

# Definimos al optimizador de la red, para que minimice el error.
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.05).minimize(loss)

n_steps = 1000 # Número de ciclos de entrenamiento.

iPY = [] # Aquí guardaremos la evolución de las predicción, para la animación.

with tf.Session() as sess:
  
  # Inicializamos todos los parámetros de la red, las matrices W y b.
  sess.run(tf.global_variables_initializer())
    
  # Iteramos n pases de entrenamiento.
  for step in range(n_steps):
  
    # Evaluamos al optimizador, a la función de coste y al tensor de salida pY. 
    # La evaluación del optimizer producirá el entrenamiento de la red.
    _, _loss, _pY = sess.run([optimizer, loss, pY], feed_dict={ iX : X, iY : Y })
    
    # Cada 25 iteraciones, imprimimos métricas.
    if step % 25 == 0: 
      
      # Cálculo del accuracy.
      acc = np.mean(np.round(_pY) == Y)
      
      # Impresión de métricas.
      print('Step', step, '/', n_steps, '- Loss = ', _loss, '- Acc =', acc)
      
      # Obtenemos predicciones para cada punto de nuestro mapa de predicción _pX.
      _pY = sess.run(pY, feed_dict={ iX : _pX }).reshape((res, res))

      # Y lo guardamos para visualizar la animación.
      iPY.append(_pY)
      
  
# ----- CÓDIGO ANIMACIÓN ----- #

ims = []

fig = plt.figure(figsize=(10, 10))

print("--- Generando animación ---")

for fr in range(len(iPY)):
  
  im = plt.pcolormesh(_x0, _x1, iPY[fr], cmap="coolwarm", animated=True)

  # Visualización de la nube de datos.
  plt.scatter(X[Y == 0,0], X[Y == 0,1], c="skyblue")
  plt.scatter(X[Y == 1,0], X[Y == 1,1], c="salmon")

  # plt.title("Resultado Clasificación")
  plt.tick_params(labelbottom=False, labelleft=False)

  ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True, repeat_delay=1000)

HTML(ani.to_html5_video())
# Out:
# Step 0 / 1000 - Loss =  0.42347768 - Acc = 0.286
# Step 25 / 1000 - Loss =  0.3954177 - Acc = 0.36
# Step 50 / 1000 - Loss =  0.3812329 - Acc = 0.406
# Step 75 / 1000 - Loss =  0.37146217 - Acc = 0.416
# Step 100 / 1000 - Loss =  0.3634697 - Acc = 0.416
# Step 125 / 1000 - Loss =  0.35592845 - Acc = 0.418
# Step 150 / 1000 - Loss =  0.34730306 - Acc = 0.426
# Step 175 / 1000 - Loss =  0.33452603 - Acc = 0.438
# Step 200 / 1000 - Loss =  0.31069994 - Acc = 0.422
# Step 225 / 1000 - Loss =  0.27398115 - Acc = 0.38
# Step 250 / 1000 - Loss =  0.24993335 - Acc = 0.5
# Step 275 / 1000 - Loss =  0.23791035 - Acc = 0.5
# Step 300 / 1000 - Loss =  0.23059799 - Acc = 0.5
# Step 325 / 1000 - Loss =  0.22511348 - Acc = 0.5
# Step 350 / 1000 - Loss =  0.22043237 - Acc = 0.5
# Step 375 / 1000 - Loss =  0.21624334 - Acc = 0.5
# Step 400 / 1000 - Loss =  0.21244003 - Acc = 0.624
# Step 425 / 1000 - Loss =  0.20893507 - Acc = 0.682
# Step 450 / 1000 - Loss =  0.2056023 - Acc = 0.712
# Step 475 / 1000 - Loss =  0.20237052 - Acc = 0.742
# Step 500 / 1000 - Loss =  0.19926143 - Acc = 0.764
# Step 525 / 1000 - Loss =  0.19621626 - Acc = 0.77
# Step 550 / 1000 - Loss =  0.19323353 - Acc = 0.776
# Step 575 / 1000 - Loss =  0.19029099 - Acc = 0.784
# Step 600 / 1000 - Loss =  0.18739028 - Acc = 0.792
# Step 625 / 1000 - Loss =  0.1845489 - Acc = 0.8
# Step 650 / 1000 - Loss =  0.1817776 - Acc = 0.8
# Step 675 / 1000 - Loss =  0.17902744 - Acc = 0.802
# Step 700 / 1000 - Loss =  0.17629384 - Acc = 0.81
# Step 725 / 1000 - Loss =  0.1736565 - Acc = 0.818
# Step 750 / 1000 - Loss =  0.17097867 - Acc = 0.822
# Step 775 / 1000 - Loss =  0.16815048 - Acc = 0.826
# Step 800 / 1000 - Loss =  0.16454372 - Acc = 0.83
# Step 825 / 1000 - Loss =  0.15607898 - Acc = 0.832
# Step 850 / 1000 - Loss =  0.14543185 - Acc = 0.906
# Step 875 / 1000 - Loss =  0.13457736 - Acc = 0.926
# Step 900 / 1000 - Loss =  0.124777295 - Acc = 0.94
# Step 925 / 1000 - Loss =  0.11642685 - Acc = 0.954
# Step 950 / 1000 - Loss =  0.10862758 - Acc = 0.96
# Step 975 / 1000 - Loss =  0.101578936 - Acc = 0.976
# --- Generando animación ---
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Keras

# %%
import tensorflow as tf
import tensorflow.keras as kr

from IPython.core.display import display, HTML


lr = 0.01           # learning rate
nn = [2, 16, 8, 1]  # número de neuronas por capa.


# Creamos el objeto que contendrá a nuestra red neuronal, como
# secuencia de capas.
model = kr.Sequential()

# Añadimos la capa 1
l1 = model.add(kr.layers.Dense(nn[1], activation='relu'))

# Añadimos la capa 2
l2 = model.add(kr.layers.Dense(nn[2], activation='relu'))

# Añadimos la capa 3
l3 = model.add(kr.layers.Dense(nn[3], activation='sigmoid'))

# Compilamos el modelo, definiendo la función de coste y el optimizador.
model.compile(loss='mse', optimizer=kr.optimizers.SGD(lr=0.05), metrics=['acc'])

# Y entrenamos al modelo. Los callbacks 
model.fit(X, Y, epochs=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Train on 500 samples
# Epoch 1/100
# 500/500 [==============================] - 0s 227us/sample - loss: 0.2668 - acc: 0.5040
# Epoch 2/100
# 500/500 [==============================] - 0s 49us/sample - loss: 0.2641 - acc: 0.4780
# Epoch 3/100
# 500/500 [==============================] - 0s 46us/sample - loss: 0.2616 - acc: 0.4600
# Epoch 4/100
# 500/500 [==============================] - 0s 51us/sample - loss: 0.2595 - acc: 0.4380
# Epoch 5/100
# 500/500 [==============================] - 0s 49us/sample - loss: 0.2577 - acc: 0.4300
# Epoch 6/100
# 500/500 [==============================] - 0s 50us/sample - loss: 0.2560 - acc: 0.4040
# Epoch 7/100
# 500/500 [==============================] - 0s 63us/sample - loss: 0.2545 - acc: 0.4060
# Epoch 8/100
# 500/500 [==============================] - 0s 54us/sample - loss: 0.2531 - acc: 0.4220
# Epoch 9/100
# 500/500 [==============================] - 0s 58us/sample - loss: 0.2516 - acc: 0.4020
# Epoch 10/100
# 500/500 [==============================] - 0s 56us/sample - loss: 0.2502 - acc: 0.3760
# Epoch 11/100
# 500/500 [==============================] - 0s 54us/sample - loss: 0.2488 - acc: 0.4060
# Epoch 12/100
# 500/500 [==============================] - 0s 53us/sample - loss: 0.2475 - acc: 0.4080
# Epoch 13/100
# 500/500 [==============================] - 0s 51us/sample - loss: 0.2462 - acc: 0.4360
# Epoch 14/100
# 500/500 [==============================] - 0s 50us/sample - loss: 0.2448 - acc: 0.5060
# Epoch 15/100
# 500/500 [==============================] - 0s 50us/sample - loss: 0.2434 - acc: 0.5200
# Epoch 16/100
# 500/500 [==============================] - 0s 51us/sample - loss: 0.2421 - acc: 0.5360
# Epoch 17/100
# 500/500 [==============================] - 0s 83us/sample - loss: 0.2406 - acc: 0.5380
# Epoch 18/100
# 500/500 [==============================] - 0s 51us/sample - loss: 0.2392 - acc: 0.5620
# Epoch 19/100
# 500/500 [==============================] - 0s 47us/sample - loss: 0.2377 - acc: 0.5860
# Epoch 20/100
# 500/500 [==============================] - 0s 48us/sample - loss: 0.2361 - acc: 0.5580
# Epoch 21/100
# 500/500 [==============================] - 0s 49us/sample - loss: 0.2345 - acc: 0.6480
# Epoch 22/100
# 500/500 [==============================] - 0s 60us/sample - loss: 0.2329 - acc: 0.6540
# Epoch 23/100
# 500/500 [==============================] - 0s 50us/sample - loss: 0.2312 - acc: 0.7060
# Epoch 24/100
# 500/500 [==============================] - 0s 53us/sample - loss: 0.2295 - acc: 0.7180
# Epoch 25/100
# 500/500 [==============================] - 0s 48us/sample - loss: 0.2275 - acc: 0.7480
# Epoch 26/100
# 500/500 [==============================] - 0s 51us/sample - loss: 0.2257 - acc: 0.7880
# Epoch 27/100
# 500/500 [==============================] - 0s 50us/sample - loss: 0.2238 - acc: 0.8180
# Epoch 28/100
# 500/500 [==============================] - 0s 52us/sample - loss: 0.2216 - acc: 0.8420
# Epoch 29/100
# 500/500 [==============================] - 0s 52us/sample - loss: 0.2195 - acc: 0.8560
# Epoch 30/100
# 500/500 [==============================] - 0s 51us/sample - loss: 0.2174 - acc: 0.8820
# Epoch 31/100
# 500/500 [==============================] - 0s 54us/sample - loss: 0.2150 - acc: 0.9020
# Epoch 32/100
# 500/500 [==============================] - 0s 57us/sample - loss: 0.2126 - acc: 0.9000
# Epoch 33/100
# 500/500 [==============================] - 0s 52us/sample - loss: 0.2100 - acc: 0.9300
# Epoch 34/100
# 500/500 [==============================] - 0s 52us/sample - loss: 0.2072 - acc: 0.9240
# Epoch 35/100
# 500/500 [==============================] - 0s 57us/sample - loss: 0.2041 - acc: 0.9580
# Epoch 36/100
# 500/500 [==============================] - 0s 59us/sample - loss: 0.2009 - acc: 0.9560
# Epoch 37/100
# 500/500 [==============================] - 0s 54us/sample - loss: 0.1976 - acc: 0.9680
# Epoch 38/100
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1945 - acc: 0.9740
# Epoch 39/100
# 500/500 [==============================] - 0s 56us/sample - loss: 0.1911 - acc: 0.9760
# Epoch 40/100
# 500/500 [==============================] - 0s 56us/sample - loss: 0.1877 - acc: 0.9800
# Epoch 41/100
# 500/500 [==============================] - 0s 50us/sample - loss: 0.1840 - acc: 0.9800
# Epoch 42/100
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1801 - acc: 0.9840
# Epoch 43/100
# 500/500 [==============================] - 0s 56us/sample - loss: 0.1763 - acc: 0.9840
# Epoch 44/100
# 500/500 [==============================] - 0s 49us/sample - loss: 0.1721 - acc: 0.9860
# Epoch 45/100
# 500/500 [==============================] - 0s 58us/sample - loss: 0.1677 - acc: 0.9900
# Epoch 46/100
# 500/500 [==============================] - 0s 59us/sample - loss: 0.1631 - acc: 0.9900
# Epoch 47/100
# 500/500 [==============================] - 0s 49us/sample - loss: 0.1585 - acc: 0.9900
# Epoch 48/100
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1540 - acc: 0.9960
# Epoch 49/100
# 500/500 [==============================] - 0s 57us/sample - loss: 0.1492 - acc: 0.9960
# Epoch 50/100
# 500/500 [==============================] - 0s 59us/sample - loss: 0.1447 - acc: 0.9960
# Epoch 51/100
# 500/500 [==============================] - 0s 53us/sample - loss: 0.1400 - acc: 0.9960
# Epoch 52/100
# 500/500 [==============================] - 0s 47us/sample - loss: 0.1354 - acc: 0.9960
# Epoch 53/100
# 500/500 [==============================] - 0s 55us/sample - loss: 0.1307 - acc: 0.9980
# Epoch 54/100
# 500/500 [==============================] - 0s 48us/sample - loss: 0.1262 - acc: 0.9980
# Epoch 55/100
# 500/500 [==============================] - 0s 44us/sample - loss: 0.1215 - acc: 0.9980
# Epoch 56/100
# 500/500 [==============================] - 0s 45us/sample - loss: 0.1173 - acc: 0.9980
# Epoch 57/100
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1128 - acc: 1.0000
# Epoch 58/100
# 500/500 [==============================] - 0s 50us/sample - loss: 0.1085 - acc: 0.9980
# Epoch 59/100
# 500/500 [==============================] - 0s 45us/sample - loss: 0.1043 - acc: 0.9980
# Epoch 60/100
# 500/500 [==============================] - 0s 48us/sample - loss: 0.1001 - acc: 1.0000
# Epoch 61/100
# 500/500 [==============================] - 0s 45us/sample - loss: 0.0960 - acc: 1.0000
# Epoch 62/100
# 500/500 [==============================] - 0s 46us/sample - loss: 0.0921 - acc: 1.0000
# Epoch 63/100
# 500/500 [==============================] - 0s 61us/sample - loss: 0.0883 - acc: 1.0000
# Epoch 64/100
# 500/500 [==============================] - 0s 49us/sample - loss: 0.0845 - acc: 1.0000
# Epoch 65/100
# 500/500 [==============================] - 0s 60us/sample - loss: 0.0810 - acc: 1.0000
# Epoch 66/100
# 500/500 [==============================] - 0s 52us/sample - loss: 0.0775 - acc: 1.0000
# Epoch 67/100
# 500/500 [==============================] - 0s 51us/sample - loss: 0.0742 - acc: 1.0000
# Epoch 68/100
# 500/500 [==============================] - 0s 57us/sample - loss: 0.0710 - acc: 1.0000
# Epoch 69/100
# 500/500 [==============================] - 0s 52us/sample - loss: 0.0679 - acc: 1.0000
# Epoch 70/100
# 500/500 [==============================] - 0s 49us/sample - loss: 0.0650 - acc: 1.0000
# Epoch 71/100
# 500/500 [==============================] - 0s 58us/sample - loss: 0.0622 - acc: 1.0000
# Epoch 72/100
# 500/500 [==============================] - 0s 52us/sample - loss: 0.0595 - acc: 1.0000
# Epoch 73/100
# 500/500 [==============================] - 0s 47us/sample - loss: 0.0570 - acc: 1.0000
# Epoch 74/100
# 500/500 [==============================] - 0s 52us/sample - loss: 0.0546 - acc: 1.0000
# Epoch 75/100
# 500/500 [==============================] - 0s 53us/sample - loss: 0.0522 - acc: 1.0000
# Epoch 76/100
# 500/500 [==============================] - 0s 58us/sample - loss: 0.0500 - acc: 1.0000
# Epoch 77/100
# 500/500 [==============================] - 0s 55us/sample - loss: 0.0479 - acc: 1.0000
# Epoch 78/100
# 500/500 [==============================] - 0s 48us/sample - loss: 0.0459 - acc: 1.0000
# Epoch 79/100
# 500/500 [==============================] - 0s 58us/sample - loss: 0.0440 - acc: 1.0000
# Epoch 80/100
# 500/500 [==============================] - 0s 45us/sample - loss: 0.0422 - acc: 1.0000
# Epoch 81/100
# 500/500 [==============================] - 0s 55us/sample - loss: 0.0405 - acc: 1.0000
# Epoch 82/100
# 500/500 [==============================] - 0s 44us/sample - loss: 0.0389 - acc: 1.0000
# Epoch 83/100
# 500/500 [==============================] - 0s 59us/sample - loss: 0.0373 - acc: 1.0000
# Epoch 84/100
# 500/500 [==============================] - 0s 77us/sample - loss: 0.0359 - acc: 1.0000
# Epoch 85/100
# 500/500 [==============================] - 0s 50us/sample - loss: 0.0345 - acc: 1.0000
# Epoch 86/100
# 500/500 [==============================] - 0s 49us/sample - loss: 0.0332 - acc: 1.0000
# Epoch 87/100
# 500/500 [==============================] - 0s 55us/sample - loss: 0.0319 - acc: 1.0000
# Epoch 88/100
# 500/500 [==============================] - 0s 55us/sample - loss: 0.0307 - acc: 1.0000
# Epoch 89/100
# 500/500 [==============================] - 0s 56us/sample - loss: 0.0296 - acc: 1.0000
# Epoch 90/100
# 500/500 [==============================] - 0s 48us/sample - loss: 0.0285 - acc: 1.0000
# Epoch 91/100
# 500/500 [==============================] - 0s 53us/sample - loss: 0.0275 - acc: 1.0000
# Epoch 92/100
# 500/500 [==============================] - 0s 54us/sample - loss: 0.0265 - acc: 1.0000
# Epoch 93/100
# 500/500 [==============================] - 0s 48us/sample - loss: 0.0256 - acc: 1.0000
# Epoch 94/100
# 500/500 [==============================] - 0s 46us/sample - loss: 0.0247 - acc: 1.0000
# Epoch 95/100
# 500/500 [==============================] - 0s 48us/sample - loss: 0.0239 - acc: 1.0000
# Epoch 96/100
# 500/500 [==============================] - 0s 55us/sample - loss: 0.0231 - acc: 1.0000
# Epoch 97/100
# 500/500 [==============================] - 0s 50us/sample - loss: 0.0223 - acc: 1.0000
# Epoch 98/100
# 500/500 [==============================] - 0s 51us/sample - loss: 0.0216 - acc: 1.0000
# Epoch 99/100
# 500/500 [==============================] - 0s 46us/sample - loss: 0.0209 - acc: 1.0000
# Epoch 100/100
# 500/500 [==============================] - 0s 47us/sample - loss: 0.0203 - acc: 1.0000

# %% [markdown]
# ## Sklearn

# %%
import sklearn as sk
import sklearn.neural_network

from IPython.core.display import display, HTML


lr = 0.01           # learning rate
nn = [2, 16, 8, 1]  # número de neuronas por capa.

# Creamos el objeto del modelo de red neuronal multicapa.
clf = sk.neural_network.MLPRegressor(solver='sgd', 
                                     learning_rate_init=lr, 
                                     hidden_layer_sizes=tuple(nn[1:]),
                                     verbose=True,
                                     n_iter_no_change=1000,
                                     batch_size = 64)


# Y lo entrenamos con nuestro datos.
clf.fit(X, Y)
# Out:
# Iteration 1, loss = 0.21047390
# Iteration 2, loss = 0.14196418
# Iteration 3, loss = 0.12163958
# Iteration 4, loss = 0.11366242
# Iteration 5, loss = 0.10600121
# Iteration 6, loss = 0.09951111
# Iteration 7, loss = 0.09418002
# Iteration 8, loss = 0.09009312
# Iteration 9, loss = 0.08774664
# Iteration 10, loss = 0.08503134
# Iteration 11, loss = 0.08216273
# Iteration 12, loss = 0.07873089
# Iteration 13, loss = 0.07691952
# Iteration 14, loss = 0.07312386
# Iteration 15, loss = 0.06979552
# Iteration 16, loss = 0.06640771
# Iteration 17, loss = 0.06321328
# Iteration 18, loss = 0.05974223
# Iteration 19, loss = 0.05594523
# Iteration 20, loss = 0.05130360
# Iteration 21, loss = 0.04709451
# Iteration 22, loss = 0.04201526
# Iteration 23, loss = 0.03694974
# Iteration 24, loss = 0.03218322
# Iteration 25, loss = 0.02733927
# Iteration 26, loss = 0.02289657
# Iteration 27, loss = 0.01914647
# Iteration 28, loss = 0.01568076
# Iteration 29, loss = 0.01302406
# Iteration 30, loss = 0.01113941
# Iteration 31, loss = 0.00998238
# Iteration 32, loss = 0.00907343
# Iteration 33, loss = 0.00828627
# Iteration 34, loss = 0.00779205
# Iteration 35, loss = 0.00723225
# Iteration 36, loss = 0.00689347
# Iteration 37, loss = 0.00650034
# Iteration 38, loss = 0.00624529
# Iteration 39, loss = 0.00612083
# Iteration 40, loss = 0.00579671
# Iteration 41, loss = 0.00569720
# Iteration 42, loss = 0.00557735
# Iteration 43, loss = 0.00537856
# Iteration 44, loss = 0.00542352
# Iteration 45, loss = 0.00530559
# Iteration 46, loss = 0.00519743
# Iteration 47, loss = 0.00516718
# Iteration 48, loss = 0.00514376
# Iteration 49, loss = 0.00507850
# Iteration 50, loss = 0.00504157
# Iteration 51, loss = 0.00496865
# Iteration 52, loss = 0.00495725
# Iteration 53, loss = 0.00498454
# Iteration 54, loss = 0.00489795
# Iteration 55, loss = 0.00493111
# Iteration 56, loss = 0.00482206
# Iteration 57, loss = 0.00484377
# Iteration 58, loss = 0.00485908
# Iteration 59, loss = 0.00484146
# Iteration 60, loss = 0.00475263
# Iteration 61, loss = 0.00478061
# Iteration 62, loss = 0.00479709
# Iteration 63, loss = 0.00476140
# Iteration 64, loss = 0.00484763
# Iteration 65, loss = 0.00473108
# Iteration 66, loss = 0.00471590
# Iteration 67, loss = 0.00471086
# Iteration 68, loss = 0.00470530
# Iteration 69, loss = 0.00470668
# Iteration 70, loss = 0.00469928
# Iteration 71, loss = 0.00469730
# Iteration 72, loss = 0.00473936
# Iteration 73, loss = 0.00468503
# Iteration 74, loss = 0.00465684
# Iteration 75, loss = 0.00459789
# Iteration 76, loss = 0.00465334
# Iteration 77, loss = 0.00462539
# Iteration 78, loss = 0.00461698
# Iteration 79, loss = 0.00463694
# Iteration 80, loss = 0.00479391
# Iteration 81, loss = 0.00461188
# Iteration 82, loss = 0.00460032
# Iteration 83, loss = 0.00465563
# Iteration 84, loss = 0.00462249
# Iteration 85, loss = 0.00460340
# Iteration 86, loss = 0.00456566
# Iteration 87, loss = 0.00456085
# Iteration 88, loss = 0.00456270
# Iteration 89, loss = 0.00461247
# Iteration 90, loss = 0.00474245
# Iteration 91, loss = 0.00464872
# Iteration 92, loss = 0.00455734
# Iteration 93, loss = 0.00458259
# Iteration 94, loss = 0.00450502
# Iteration 95, loss = 0.00453348
# Iteration 96, loss = 0.00451925
# Iteration 97, loss = 0.00450315
# Iteration 98, loss = 0.00461000
# Iteration 99, loss = 0.00450893
# Iteration 100, loss = 0.00449101
# Iteration 101, loss = 0.00454201
# Iteration 102, loss = 0.00451648
# Iteration 103, loss = 0.00449058
# Iteration 104, loss = 0.00455789
# Iteration 105, loss = 0.00451489
# Iteration 106, loss = 0.00449826
# Iteration 107, loss = 0.00453458
# Iteration 108, loss = 0.00452112
# Iteration 109, loss = 0.00452493
# Iteration 110, loss = 0.00448365
# Iteration 111, loss = 0.00445387
# Iteration 112, loss = 0.00445653
# Iteration 113, loss = 0.00447797
# Iteration 114, loss = 0.00448375
# Iteration 115, loss = 0.00446778
# Iteration 116, loss = 0.00447918
# Iteration 117, loss = 0.00443693
# Iteration 118, loss = 0.00449150
# Iteration 119, loss = 0.00447434
# Iteration 120, loss = 0.00457851
# Iteration 121, loss = 0.00444697
# Iteration 122, loss = 0.00447729
# Iteration 123, loss = 0.00444012
# Iteration 124, loss = 0.00443290
# Iteration 125, loss = 0.00443591
# Iteration 126, loss = 0.00444055
# Iteration 127, loss = 0.00442062
# Iteration 128, loss = 0.00441332
# Iteration 129, loss = 0.00444314
# Iteration 130, loss = 0.00444323
# Iteration 131, loss = 0.00443848
# Iteration 132, loss = 0.00438329
# Iteration 133, loss = 0.00447166
# Iteration 134, loss = 0.00437542
# Iteration 135, loss = 0.00445183
# Iteration 136, loss = 0.00437665
# Iteration 137, loss = 0.00439166
# Iteration 138, loss = 0.00439328
# Iteration 139, loss = 0.00433581
# Iteration 140, loss = 0.00440135
# Iteration 141, loss = 0.00444095
# Iteration 142, loss = 0.00434984
# Iteration 143, loss = 0.00434693
# Iteration 144, loss = 0.00436530
# Iteration 145, loss = 0.00435864
# Iteration 146, loss = 0.00433511
# Iteration 147, loss = 0.00437829
# Iteration 148, loss = 0.00433998
# Iteration 149, loss = 0.00437999
# Iteration 150, loss = 0.00432605
# Iteration 151, loss = 0.00436694
# Iteration 152, loss = 0.00436458
# Iteration 153, loss = 0.00432661
# Iteration 154, loss = 0.00436669
# Iteration 155, loss = 0.00440203
# Iteration 156, loss = 0.00429748
# Iteration 157, loss = 0.00431880
# Iteration 158, loss = 0.00438695
# Iteration 159, loss = 0.00431857
# Iteration 160, loss = 0.00428931
# Iteration 161, loss = 0.00438064
# Iteration 162, loss = 0.00429447
# Iteration 163, loss = 0.00434676
# Iteration 164, loss = 0.00436094
# Iteration 165, loss = 0.00428061
# Iteration 166, loss = 0.00427802
# Iteration 167, loss = 0.00428112
# Iteration 168, loss = 0.00426969
# Iteration 169, loss = 0.00426571
# Iteration 170, loss = 0.00425149
# Iteration 171, loss = 0.00435213
# Iteration 172, loss = 0.00428001
# Iteration 173, loss = 0.00427356
# Iteration 174, loss = 0.00427805
# Iteration 175, loss = 0.00424918
# Iteration 176, loss = 0.00427388
# Iteration 177, loss = 0.00430080
# Iteration 178, loss = 0.00426431
# Iteration 179, loss = 0.00429156
# Iteration 180, loss = 0.00426694
# Iteration 181, loss = 0.00424768
# Iteration 182, loss = 0.00425018
# Iteration 183, loss = 0.00426121
# Iteration 184, loss = 0.00428941
# Iteration 185, loss = 0.00429302
# Iteration 186, loss = 0.00425031
# Iteration 187, loss = 0.00421603
# Iteration 188, loss = 0.00429970
# Iteration 189, loss = 0.00425981
# Iteration 190, loss = 0.00426598
# Iteration 191, loss = 0.00430572
# Iteration 192, loss = 0.00432882
# Iteration 193, loss = 0.00429730
# Iteration 194, loss = 0.00427886
# Iteration 195, loss = 0.00423274
# Iteration 196, loss = 0.00425017
# Iteration 197, loss = 0.00422490
# Iteration 198, loss = 0.00428719
# Iteration 199, loss = 0.00419700
# Iteration 200, loss = 0.00421158
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# MLPRegressor(batch_size=64, hidden_layer_sizes=(16, 8, 1),
#              learning_rate_init=0.01, n_iter_no_change=1000, solver='sgd',
#              verbose=True)
